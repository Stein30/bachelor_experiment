# %%
import numpy as np
from pykrige.rk import Krige
from sklearn.model_selection import GridSearchCV

# 3D Kring param opt
param_dict3d = {
    "method": ["ordinary3d","universal3d"],
    "variogram_model": ["linear", "power", "gaussian", "spherical"],
# "nlags": [4, 6, 8],
# "weight": [True, False]
}

estimator = GridSearchCV(Krige(), param_dict3d, verbose=True, return_train_score=True)

file_name =  'output2.xlsx'
import pandas as pd
dfx= pd.read_excel(io=file_name, usecols=[3,7,8,9,10])
print(dfx)
df_ss = dfx[dfx['geo'].str.contains('Ss')] #砂岩
dfx_ss = df_ss.drop(['geo','depth'], axis=1)
dfx_y = df_ss.drop(['lat','lon','alt','geo'], axis=1)

X3 = dfx_ss.to_numpy()
y = dfx_y.to_numpy()

# run the gridsearch
estimator.fit(X=X3, y=y)

if hasattr(estimator, "best_score_"):
    print("best_score R2 = {:.3f}".format(estimator.best_score_))
    print("best_params = ", estimator.best_params_)
    print("\nCV results::")
if hasattr(estimator, "cv_results_"):
    for key in [
        "mean_test_score",
        "mean_train_score",
        "param_method",
        "param_variogram_model",
    ]:
        print(" - {} : {}".format(key, estimator.cv_results_[key]))
# Out:
#              lon        lat    alt  depth geo
# 0     135.145398  34.144783   5.34   1.00   M
# 1     135.145398  34.144783   5.34   1.90   M
# 2     135.145598  34.145683   5.90   0.95   M
# 3     135.145598  34.145683   5.90   1.30  sd
# 4     135.145598  34.145683   5.90   2.30  GF
# ...          ...        ...    ...    ...  ..
# 2022  135.291670  34.165433  49.03   6.10   G
# 2023  135.291670  34.165433  49.03   9.10   C
# 2024  135.291770  34.165713  50.54   0.60   G
# 2025  135.291770  34.165713  50.54   1.70  sd
# 2026  135.291770  34.165713  50.54   9.00   G
#
# [2027 rows x 5 columns]
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/ok3d.py", line 350, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py:853: RuntimeWarning: invalid value encountered in sqrt
#   sigma[i] = np.sqrt(ss)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/ok3d.py", line 350, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/ok3d.py", line 350, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/uk3d.py", line 378, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# /opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py:853: RuntimeWarning: invalid value encountered in sqrt
#   sigma[i] = np.sqrt(ss)
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/uk3d.py", line 378, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/rk.py", line 202, in fit
#     self.model = krige_methods[self.method](**input_kw)
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/uk3d.py", line 378, in __init__
#     self.delta, self.sigma, self.epsilon = _find_statistics(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 835, in _find_statistics
#     k, ss = _krige(
#   File "/opt/anaconda3/lib/python3.8/site-packages/pykrige/core.py", line 777, in _krige
#     res = np.linalg.solve(a, b)
#   File "<__array_function__ internals>", line 5, in solve
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 399, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py", line 97, in _raise_linalgerror_singular
#     raise LinAlgError("Singular matrix")
# numpy.linalg.LinAlgError: Singular matrix
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# n_closest_points will be ignored for UniversalKriging
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:   29.2s finished
# best_score R2 = -0.560
# best_params =  {'method': 'ordinary3d', 'variogram_model': 'power'}
#
# CV results::
#  - mean_test_score : [        nan -0.56024            nan -0.72337201         nan -9.40011851
#          nan -1.4134325 ]
#  - mean_train_score : [         nan   0.28708098          nan   0.45502603          nan
#  -32.55020287          nan  -1.80876517]
#  - param_method : ['ordinary3d' 'ordinary3d' 'ordinary3d' 'ordinary3d' 'universal3d'
#  'universal3d' 'universal3d' 'universal3d']
#  - param_variogram_model : ['linear' 'power' 'gaussian' 'spherical' 'linear' 'power' 'gaussian'
#  'spherical']

# %%
x_a = np.array([[135.1552, 34.16521, 117.72]])
print(estimator.predict(x_a))
# Out:
# [13.55702415]

# %%
import numpy as np
from pykrige.rk import Krige
from sklearn.model_selection import GridSearchCV

# 3D Kring param opt
param_dict3d = {
    "method": ["ordinary3d"],
    "variogram_model": ["linear", "power", "gaussian", "spherical"],
# "nlags": [4, 6, 8],
# "weight": [True, False]
}

estimator = GridSearchCV(Krige(), param_dict3d, verbose=True, return_train_score=True)
file_name =  'output2.xlsx'
import pandas as pd

dfx= pd.read_excel(io=file_name, usecols=[3,7,8,9,10])

# %%
#section 1

df_sec1 = dfx[dfx['lat'] < 34.172] 
dfx_sec1 = df_sec1[df_sec1['lon'] < 135.18]

df1_ss = dfx_sec1[dfx_sec1['geo'].str.contains('Ss')] #砂岩

#layer loop start
a = df1_ss.to_numpy()

l = len(a)
j = 0
maxj = 0
a[0, 4] = 'Ss' + str(j)

for i in range(1,l):
    if a[i, 0] == a[i-1, 0] and a[i, 1] == a[i-1, 1]:
        j = j + 1
        a[i, 4] = 'Ss' + str(j)
        if maxj < j:
            maxj = j
    else:
        j = 0
        a[i, 4] = 'Ss' + str(j)
        
print(maxj)

column = ['lat', 'lon', 'alt', 'depth', 'geo']
dfs1 = pd.DataFrame(data=a, columns=column)
#print(dfs1)
#layer loop end

pd.set_option('display.max_rows', dfx.shape[0]+1)
print(len(df1_ss))
print(len(dfs1))

# %%
for i in range(maxj):
    geo = 'Ss' + str(i)
    dfxs1 = dfs1[dfs1['geo'].str.contains(geo)] #砂岩
    
    dfx1_ss = dfxs1.drop(['geo','depth'], axis=1)
    dfx1_y = dfxs1.drop(['lat','lon','alt','geo'], axis=1)

    X1 = dfx1_ss.to_numpy()
    y = dfx1_y.to_numpy()
    
    print(geo, len(dfxs1))
    estimator.fit(X=X1, y=y)
    if hasattr(estimator, "best_score_"):
        print("best_score R2 = {:.3f}".format(estimator.best_score_))
        print("best_params = ", estimator.best_params_)
        print("\nCV results::")
    if hasattr(estimator, "cv_results_"):
        for key in [
            "mean_test_score",
            "mean_train_score",
            "param_method",
            "param_variogram_model",
        ]:
            print(" - {} : {}".format(key, estimator.cv_results_[key]))

# %%
#section 2

df_sec2 = dfx[dfx['lat'] < 34.172] 
dfx_sec2 = df_sec2[df_sec2['lon'] >= 135.18]

df2_ss = dfx_sec2[dfx_sec2['geo'].str.contains('Ss')]  #砂岩

#layer loop start
a = df2_ss.to_numpy()

l = len(a)
j = 0
maxj = 0
a[0, 4] = 'Ss' + str(j)

for i in range(1,l):
    if a[i, 0] == a[i-1, 0] and a[i, 1] == a[i-1, 1]:
        j = j + 1
        a[i, 4] = 'Ss' + str(j)
        if maxj < j:
            maxj = j
    else:
        j = 0
        a[i, 4] = 'Ss' + str(j)
        
print(maxj)

column = ['lat', 'lon', 'alt', 'depth', 'geo']
dfs2 = pd.DataFrame(data=a, columns=column)
#print(dfs1)
#layer loop end

pd.set_option('display.max_rows', dfx.shape[0]+1)
print(len(df2_ss))
print(len(dfs2))

# %%
for i in range(maxj):
    geo = 'Ss' + str(i)
    dfxs2 = dfs2[dfs2['geo'].str.contains(geo)] #砂岩
    
    dfx2_ss = dfxs2.drop(['geo','depth'], axis=1)
    dfx2_y = dfxs2.drop(['lat','lon','alt','geo'], axis=1)

    X2 = dfx2_ss.to_numpy()
    y2 = dfx2_y.to_numpy()
    
    print(geo, len(dfxs2))
    estimator.fit(X=X2, y=y2)
    if hasattr(estimator, "best_score_"):
        print("best_score R2 = {:.3f}".format(estimator.best_score_))
        print("best_params = ", estimator.best_params_)
        print("\nCV results::")
    if hasattr(estimator, "cv_results_"):
        for key in [
            "mean_test_score",
            "mean_train_score",
            "param_method",
            "param_variogram_model",
        ]:
            print(" - {} : {}".format(key, estimator.cv_results_[key]))

# %%
#section 3

df_sec3 = dfx[dfx['lat'] >= 34.172] 
dfx_sec3 = df_sec3[df_sec3['lon'] >= 135.18]

df3_ss = dfx_sec3[dfx_sec3['geo'].str.contains('Ss')]  #砂岩

#layer loop start
a = df3_ss.to_numpy()

l = len(a)
j = 0
maxj = 0
a[0, 4] = 'Ss' + str(j)

for i in range(1,l):
    if a[i, 0] == a[i-1, 0] and a[i, 1] == a[i-1, 1]:
        j = j + 1
        a[i, 4] = 'Ss' + str(j)
        if maxj < j:
            maxj = j
    else:
        j = 0
        a[i, 4] = 'Ss' + str(j)
        
print(maxj)

column = ['lat', 'lon', 'alt', 'depth', 'geo']
dfs3 = pd.DataFrame(data=a, columns=column)
#print(dfs1)
#layer loop end

pd.set_option('display.max_rows', dfx.shape[0]+1)
print(len(df3_ss))
print(len(dfs3))

# %%
for i in range(maxj):
    geo = 'Ss' + str(i)
    dfxs3 = dfs3[dfs3['geo'].str.contains(geo)] #砂岩
    
    dfx3_ss = dfxs3.drop(['geo','depth'], axis=1)
    dfx3_y = dfxs3.drop(['lat','lon','alt','geo'], axis=1)

    X3 = dfx3_ss.to_numpy()
    y = dfx3_y.to_numpy()
    
    print(geo, len(dfxs3))
    estimator.fit(X=X3, y=y)
    if hasattr(estimator, "best_score_"):
        print("best_score R2 = {:.3f}".format(estimator.best_score_))
        print("best_params = ", estimator.best_params_)
        print("\nCV results::")
    if hasattr(estimator, "cv_results_"):
        for key in [
            "mean_test_score",
            "mean_train_score",
            "param_method",
            "param_variogram_model",
        ]:
            print(" - {} : {}".format(key, estimator.cv_results_[key]))
